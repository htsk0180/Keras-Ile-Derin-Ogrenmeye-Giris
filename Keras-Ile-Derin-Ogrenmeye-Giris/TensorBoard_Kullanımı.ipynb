# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# TensorBoard notebook eklentilerini yüklemek
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# Import TensorFlow, datetime ve os:

# %%
import tensorflow as tf
import datetime, os

# %% [markdown]
# ## Keras ile Google Colab' da TensorBoard Kullanımı

# %% [markdown]
#  [FashionMNIST](https://github.com/zalandoresearch/fashion-mnist) veri kümesini yükle ve eğitim için hazırla:

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# Basit bir sinir ağoı modeli tasarlayın

# %%
def create_model():
  return tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
  ])

# %% [markdown]
# Keras ve TensorBoard callbacks (geriçağırmalar) kullanarak modeli eğitin!

# %%
def train_model():
  
  model = create_model()
  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

  logdir = os.path.join("/gdrive/My Drive/Calisma_ortami/Ciktilar/logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

  model.fit(x=x_train, 
            y=y_train, 
            epochs=5, 
            validation_data=(x_test, y_test), 
            callbacks=[tensorboard_callback])

train_model()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4955 - accuracy: 0.8231 - val_loss: 0.4043 - val_accuracy: 0.8542
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3818 - accuracy: 0.8608 - val_loss: 0.3670 - val_accuracy: 0.8657
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3502 - accuracy: 0.8727 - val_loss: 0.3937 - val_accuracy: 0.8549
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3305 - accuracy: 0.8776 - val_loss: 0.3494 - val_accuracy: 0.8735
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3138 - accuracy: 0.8845 - val_loss: 0.3401 - val_accuracy: 0.8764

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 386), started 0:09:00 ago. (Use '!kill 386' to kill it.)

# %%
train_model()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4990 - accuracy: 0.8209 - val_loss: 0.3986 - val_accuracy: 0.8583
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3832 - accuracy: 0.8598 - val_loss: 0.3879 - val_accuracy: 0.8625
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3492 - accuracy: 0.8720 - val_loss: 0.3841 - val_accuracy: 0.8612
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3297 - accuracy: 0.8789 - val_loss: 0.3452 - val_accuracy: 0.8745
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3120 - accuracy: 0.8844 - val_loss: 0.3491 - val_accuracy: 0.8771

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.
